# %%
import pandas as pd

# %%
route = r'C:\Users\abrah\Documents\PROFESSIONAL LIFE\1 projects\little penguins research\anomaly detection in time series\Anomaly-Detection-in-Time-Series-for-Animal-Behavior\data\penguin_count.csv'
column = 'nightly_crossing_number'
csv_file = pd.read_csv(route)[column]
csv_file.diff()[400:800].plot(figsize=(15,3), linewidth = 1)
# Out:
# <Axes: >
